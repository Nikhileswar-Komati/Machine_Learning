# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhileswar-Komati/Machine_Learning/blob/master/COVID/Copy_of_Covid_Research_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
files.upload()

# %%
data = pd.read_excel('/content/MHcovid.xlsx')
data.sample(5)

train = []
for i in range(0, len(data), 3):
  train.append(abs(int(data.loc[i])))

train = train[0:-1]
data = pd.DataFrame(train, columns = ['MH'])
data['DAY'] = data.index
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))

training_set = data.iloc[:200, 0:1].values
testing_set = data.iloc[200:, 0:1].values

training_set_scaled = sc.fit_transform(training_set)
training_set_scaled.shape
# Out:
# (200, 1)

# %%
step = 5
X_train = []
y_train = []
for i in range(6, 200):
    X_train.append(training_set_scaled[i-step:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
train_X = X_train
train_y = y_train
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
#(740, 60, 1)
# Out:
# (194, 5, 1)

# %%
from keras import Sequential
from keras.layers import LSTM, Dense, Dropout

model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 13ms/step - loss: 0.1472
# Epoch 2/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0899
# Epoch 3/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0566
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0448
# Epoch 5/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0224
# Epoch 6/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0093
# Epoch 7/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0088
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0092
# Epoch 9/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0068
# Epoch 10/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0093
# Epoch 11/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0077
# Epoch 12/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0068
# Epoch 13/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 14/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0074
# Epoch 15/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 16/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0069
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 18/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0061
# Epoch 19/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 20/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 21/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 22/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0058
# Epoch 23/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 24/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0068
# Epoch 25/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0075
# Epoch 26/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0102
# Epoch 27/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0053
# Epoch 28/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 29/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0061
# Epoch 30/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 31/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0072
# Epoch 32/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0069
# Epoch 33/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 34/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0054
# Epoch 35/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0061
# Epoch 36/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 37/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 38/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0067
# Epoch 39/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 40/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0067
# Epoch 41/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0061
# Epoch 42/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0067
# Epoch 43/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 44/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0093
# Epoch 45/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0052
# Epoch 46/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0069
# Epoch 47/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0067
# Epoch 48/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0092
# Epoch 49/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0060
# Epoch 50/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0046
# Epoch 51/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0062
# Epoch 52/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0071
# Epoch 53/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0069
# Epoch 54/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0071
# Epoch 55/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 56/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0058
# Epoch 57/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0064
# Epoch 58/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 59/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0052
# Epoch 60/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 61/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0074
# Epoch 62/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0073
# Epoch 63/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 64/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0062
# Epoch 65/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0069
# Epoch 66/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0080
# Epoch 67/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 68/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 69/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0076
# Epoch 70/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 71/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0080
# Epoch 72/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 73/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0086
# Epoch 74/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 75/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0069
# Epoch 76/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 77/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0066
# Epoch 78/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0062
# Epoch 79/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0072
# Epoch 80/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 81/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 82/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0076
# Epoch 83/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 84/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0058
# Epoch 85/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0059
# Epoch 86/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0061
# Epoch 87/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 88/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 89/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 90/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0071
# Epoch 91/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0055
# Epoch 92/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 93/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0050
# Epoch 94/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 95/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0077
# Epoch 96/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0058
# Epoch 97/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 98/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0049
# Epoch 99/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0058
# Epoch 100/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0071

# %%
dataset_train = data.iloc[:200, 0:1]
dataset_test = data.iloc[200:, 0:1]
dataset_total = pd.concat((dataset_train, dataset_test), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 5:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

X_test = []
for i in range(6, 87):
    X_test.append(inputs[i-step:i, 0])
X_test = np.array(X_test)
test_X = X_test
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
print(X_test.shape)
# Out:
# (81, 5, 1)

# %%
predicted_cases = model.predict(X_test)
predicted_cases = sc.inverse_transform(predicted_cases)
# Out:
# (81, 1)

# %%
# Visualising the results
plt.plot(data.loc[200:, 'DAY'].values, testing_set[:, 0], color = 'red', label = 'Real Cases')
plt.plot(data.loc[200:, 'DAY'].values, predicted_cases[:, 0], color = 'blue', label = 'Predicted Cases')
# plt.xticks(np.arange(0,459,50))
plt.title('Cases Prediction')
plt.xlabel('DAY')
plt.ylabel('CASES')
plt.legend()
plt.show()
#6

# %%
# Visualising the results
plt.plot(data.loc[200:, 'DAY'].values, testing_set[:, 0], color = 'red', label = 'Real Cases')
plt.plot(data.loc[200:, 'DAY'].values, predicted_cases[:, 0], color = 'blue', label = 'Predicted Cases')
# plt.xticks(np.arange(0,459,50))
plt.title('Cases Prediction')
plt.xlabel('DAY')
plt.ylabel('CASES')
plt.legend()
plt.show()
#5

# %%
# Visualising the results
plt.plot(data.loc[200:, 'DAY'].values, testing_set[:, 0], color = 'red', label = 'Real Cases')
plt.plot(data.loc[200:, 'DAY'].values, predicted_cases[:, 0], color = 'blue', label = 'Predicted Cases')
# plt.xticks(np.arange(0,459,50))
plt.title('Cases Prediction')
plt.xlabel('DAY')
plt.ylabel('CASES')
plt.legend()
plt.show()
#5-5

# %%
import xgboost as xgb
alg = xgb.XGBRegressor()

alg.fit(train_X, train_y)

predicted_cases = alg.predict(test_X)
predicted_cases = predicted_cases.reshape(-1, 1)
predicted_cases = sc.inverse_transform(predicted_cases)


# Visualising the results
plt.plot(data.loc[200:, 'DAY'].values, testing_set[:, 0], color = 'red', label = 'Real Cases')
plt.plot(data.loc[200:, 'DAY'].values, predicted_cases[:, 0], color = 'blue', label = 'Predicted Cases')
# plt.xticks(np.arange(0,459,50))
plt.title('Cases Prediction')
plt.xlabel('DAY')
plt.ylabel('CASES')
plt.legend()
plt.show()
# 5-5
# Out:
# [10:37:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
